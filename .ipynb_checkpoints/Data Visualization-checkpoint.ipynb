# %% [markdown]
# # Data Visualization
# Data visualization is one of the important tasks in data science project. It plays an important role when there is too much data because visualization turns huge amount of numbers into a digestible picture. Therefore, it is critical to have a good visualization in order to tell a story with number. Initium media had done quite a lot of data visualization with real life data.
#
# From https://theinitium.com/article/20150812-hongkong-legcoanalysis/
#
# ![Legco Matrix](legco_matrix.png)

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('RWC-KJZGQV0')

# %% [markdown]
# # Basics in Matplotlib
#
# Today we will go through graph plotting in Python. In this tutorial, we will be using a famous libary Matplotlib to demostrate how graph plotting is done in jupyter. Matplotlib is a common plotting library which generates 2D graphs and works well in both jupyter and IPython. The graph is in good quality which can be included into technical report and thesis. Matplotlib is designed to be simple and you can plot one graph with one single command.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Line Chart
#
# Now let's try a simple line chart.

# %%
plt.rcParams["figure.figsize"] = (20, 5)
plt.subplot(1, 3, 1)
plt.plot([1, 2, 3, 4], c='#FF00FF')
plt.subplot(1, 3, 2)
plt.title("Bold line", fontsize=20)
plt.plot([1, 2, 3, 4], linewidth=20, c='#FF00FF')
plt.subplot(1, 3, 3)
plt.plot([1, 2, 3, 4], '*-', markersize=50, c='r')

# %%
x = [1, 2, 3, 4, 5]
y = [1, 0, 1, 0, 1]
plt.plot(x, y)

# %% [markdown]
# Now let's more different kinds of graphs.
#
# 1. Bar
# 2. Histogram
# 3. Pie
# 4. Scatter

# %% [markdown]
# # Example 1: Map Visualization
# In this example, we would do a simple map visualization of Hong Kong. We get the geojson data from https://data.gov.hk/en-data/dataset/hk-had-json1-hong-kong-administrative-boundaries/resource/d2a89ff1-72d7-4523-a7de-74a57ad3e14b.

# %% [markdown]
# # Pre-requisite
# The following packages are required.
#
# ```
# geopandas
# shapely
# ```

# %% [markdown]
# Now let's read the file.

# %%
import geopandas as gpd
import pandas as pd
hkg = gpd.read_file('hkg.geojson')
del hkg['Administrative District Boundary of Hong Kong']
hkg
# Out:
#    地區號碼           District   地區  \
# 0     A  Central & Western  中西區
# 1     B           Wan Chai   灣仔
# 2     C            Eastern   東區
# 3     D           Southern   南區
# 4     E      Yau Tsim Mong  油尖旺
# 5     F       Sham Shui Po  深水埗
# 6     G       Kowloon City  九龍城
# 7     H       Wong Tai Sin  黃大仙
# 8     J          Kwun Tong   觀塘
# 9     K          Tsuen Wan   荃灣
# 10    L           Tuen Mun   屯門
# 11    M          Yuen Long   元朗
# 12    N              North   北區
# 13    P             Tai Po   大埔
# 14    Q           Sai Kung   西貢
# 15    R            Sha Tin   沙田
# 16    S         Kwai Tsing   葵青
# 17    T            Islands   離島
#
#                                              geometry
# 0   POLYGON ((114.14951 22.29748, 114.10987 22.297...
# 1   POLYGON ((114.19771 22.2579, 114.19778 22.2580...
# 2   POLYGON ((114.21939 22.29568, 114.21087 22.300...
# 3   POLYGON ((114.16338 22.25882, 114.16305 22.258...
# 4   POLYGON ((114.17448 22.32665, 114.17417 22.326...
# 5   POLYGON ((114.17273 22.34646, 114.17258 22.346...
# 6   POLYGON ((114.17946 22.34902, 114.179 22.34908...
# 7   POLYGON ((114.22403 22.33452, 114.22112 22.353...
# 8   POLYGON ((114.22403 22.33452, 114.22397 22.334...
# 9   POLYGON ((114.16919 22.41293, 114.16148 22.413...
# 10  POLYGON ((114.06597 22.39181, 114.06581 22.397...
# 11  POLYGON ((114.1279 22.46651, 114.12657 22.4661...
# 12  POLYGON ((114.33619 22.56813, 114.33296 22.568...
# 13  POLYGON ((114.45606 22.46623, 114.45492 22.468...
# 14  POLYGON ((114.30925 22.14848, 114.50246 22.148...
# 15  POLYGON ((114.25245 22.3936, 114.25246 22.394,...
# 16  POLYGON ((114.14901 22.38028, 114.14753 22.378...
# 17  POLYGON ((114.0727 22.31253, 114.01046 22.3138...

# %%
# %matplotlib inline
import matplotlib as plt
ax = hkg.plot(column='District',  figsize=(20, 20))
ax.axis('off')
ax.set_title('Hong Kong District Boundary', fontsize=40)
for idx, row in hkg.iterrows():
    pt = row['geometry'].representative_point()
    ax.annotate(s=row['District'], xy=(pt.x, pt.y),
                 horizontalalignment='center', fontsize=10)

# %%
! pip install pySAL
# Out:
# Collecting pySAL
#   Downloading https://files.pythonhosted.org/packages/db/3f/2141de9a8849f7d24878c4e633291ed1f6d9f05f801ea8746576ecba1aed/PySAL-1.14.3.tar.gz (17.8MB)
#     100% |████████████████████████████████| 17.8MB 33kB/s  eta 0:00:01    94% |██████████████████████████████▎ | 16.9MB 29.7MB/s eta 0:00:01
# Requirement already satisfied: scipy>=0.11 in /opt/conda/lib/python3.6/site-packages (from pySAL)
# Requirement already satisfied: numpy>=1.3 in /opt/conda/lib/python3.6/site-packages (from pySAL)
# Building wheels for collected packages: pySAL
#   Running setup.py bdist_wheel for pySAL ... done
#   Stored in directory: /home/jovyan/.cache/pip/wheels/fa/dd/19/2665a24ef25064d2717f2e04aa173cd7876298ef4578bf9777
# Successfully built pySAL
# Installing collected packages: pySAL
# Successfully installed pySAL-1.14.3
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
population = pd.read_csv('Population.csv')
hkg2 = hkg.merge(population, on='District')
del hkg2['Chinese']
hkg2.sort_values(by='Population', ascending=False)
# Out:
#    地區號碼       District   地區  \
# 14    R        Sha Tin   沙田
# 7     J      Kwun Tong   觀塘
# 10    M      Yuen Long   元朗
# 1     C        Eastern   東區
# 15    S     Kwai Tsing   葵青
# 9     L       Tuen Mun   屯門
# 13    Q       Sai Kung   西貢
# 6     H   Wong Tai Sin  黃大仙
# 5     G   Kowloon City  九龍城
# 4     F   Sham Shui Po  深水埗
# 3     E  Yau Tsim Mong  油尖旺
# 11    N          North   北區
# 12    P         Tai Po   大埔
# 8     K      Tsuen Wan   荃灣
# 2     D       Southern   南區
# 0     B       Wan Chai   灣仔
# 16    T        Islands   離島
#
#                                              geometry  Population    Area  \
# 14  POLYGON ((114.25245 22.3936, 114.25246 22.394,...      648200   68.71
# 7   POLYGON ((114.22403 22.33452, 114.22397 22.334...      641100   11.27
# 10  POLYGON ((114.1279 22.46651, 114.12657 22.4661...      607200  138.46
# 1   POLYGON ((114.21939 22.29568, 114.21087 22.300...      574500   18.56
# 15  POLYGON ((114.14901 22.38028, 114.14753 22.378...      507100   23.34
# 9   POLYGON ((114.06597 22.39181, 114.06581 22.397...      495900   82.89
# 13  POLYGON ((114.30925 22.14848, 114.50246 22.148...      448600  129.65
# 6   POLYGON ((114.22403 22.33452, 114.22112 22.353...      426200    9.30
# 5   POLYGON ((114.17946 22.34902, 114.179 22.34908...      405400   10.02
# 4   POLYGON ((114.17273 22.34646, 114.17258 22.346...      390600    9.35
# 3   POLYGON ((114.17448 22.32665, 114.17417 22.326...      318100    6.99
# 11  POLYGON ((114.33619 22.56813, 114.33296 22.568...      310800  136.61
# 12  POLYGON ((114.45606 22.46623, 114.45492 22.468...      307100  136.15
# 8   POLYGON ((114.16919 22.41293, 114.16148 22.413...      303600   61.71
# 2   POLYGON ((114.16338 22.25882, 114.16305 22.258...      269200   38.85
# 0   POLYGON ((114.19771 22.2579, 114.19778 22.2580...      150900    9.83
# 16  POLYGON ((114.0727 22.31253, 114.01046 22.3138...      146900  175.12
#
#      Density
# 14   9433.85
# 7   56779.05
# 10   4297.99
# 1   31217.67
# 15  21503.86
# 9    5889.38
# 13   3460.08
# 6   45645.16
# 5   40194.70
# 4   41529.41
# 3   44864.09
# 11   2220.19
# 12   2220.35
# 8    4887.38
# 2    6962.68
# 0   15300.10
# 16    825.14

# %% [markdown]
# Note: Please install `pySAL` in order to use `schema` when plotting.

# %%
# %matplotlib inline
import matplotlib as plt
ax = hkg2.plot(column='Population',  figsize=(20, 20), cmap='Dark2', scheme='quantiles')
ax.axis('off')
ax.set_title('Hong Kong District Boundary', fontsize=40)
for idx, row in hkg2.iterrows():
    pt = row['geometry'].representative_point()
    ax.annotate(s=row['District'], xy=(pt.x, pt.y),
                 horizontalalignment='center', fontsize=10)

# %% [markdown]
# # Example 2: Word Cloud
# In here, we will use `WordCloud` library at https://github.com/amueller/word_cloud.
# World cloud or tag cloud is a common text visualization nowadays. It can show most common or most important words in a website, blog, articles etc.
#
# For example, this is the word cloud of Wikimedia-l generated by IBM word cloud generator.
# ![Example word cloud](wordcloud_example.png)

# %%
from wordcloud import WordCloud
text = ""
with open("wiki_text.txt", "r") as f:
    text = f.read()
wordcloud = WordCloud(background_color="white", width=1200, height=800)
wordcloud.generate(text)
plt.figure( figsize=(20,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# #  Wordcloud Mask
# The default shape is a rectangle, we can alter the shape by providing a mask to `wordcloud` .

# %%
from PIL import Image
import numpy as np
mask_image = Image.open("docs-mask3.png")
plt.imshow(mask_image)

# %% [markdown]
# Then we turn the image into `numpy` 2D array.

# %%
circle_mask = np.array(mask_image)

# %%
wordcloud2 = WordCloud(background_color="#cccccc", mask=circle_mask)
wordcloud2.generate(text)
plt.figure( figsize=(10,10))
plt.imshow(wordcloud2)
plt.axis("off")
plt.show()

# %% [markdown]
# # Chinese Word Cloud
# What about chinese text?

# %%
chi_text = ""
with open("mingpao_example.txt", "r") as f:
    chi_text = f.read()
wordcloud_chi = WordCloud(background_color="white", width=1200, height=800)
wordcloud_chi.generate(chi_text)
plt.figure( figsize=(20,10))
plt.imshow(wordcloud_chi)
plt.axis("off")
plt.show()

# %% [markdown]
# Such a mess, because we need to use a suitable Chinese font.

# %%
wordcloud_chi = WordCloud(font_path="NotoSansCJKtc-Medium.otf", background_color="white", width=1200, height=800)
wordcloud_chi.generate(chi_text)
plt.figure( figsize=(20,10))
plt.imshow(wordcloud_chi)
plt.axis("off")
plt.show()
